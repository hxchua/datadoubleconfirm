# %% [markdown]
# #### Text-generating neural network trained using text from [Singapore's Budget 2020 - Resilience Budget/ Supplementary Budget Statement](https://www.singaporebudget.gov.sg/budget_2020/resilience-budget/supplementary-budget-statement) with textgenrnn. Instructions on how to install can be found on the official github page [here](https://github.com/minimaxir/textgenrnn).

# %%
from textgenrnn import textgenrnn

# %%
textgen = textgenrnn()

# %%
textgen.train_from_file('mof_budget_2.txt', num_epochs=10)
textgen.generate()
# Out:
# 808 texts collected.
# Training on 59,436 character sequences.
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 464 steps
# Epoch 1/10
# ...

# %%
textgen.generate(3)
# Out:
#   0%|                                                                                            | 0/3 [00:00<?, ?it/s]
# iii. Our economy will be a long-term can receive a strategic and programme to the rest of the economy.
#  33%|████████████████████████████                                                        | 1/3 [00:05<00:11,  5.96s/it]
# a. The measures of the social sector has furthered a based and industry badly and seeing an extraordinary measures to support the temporary crisis.
# 100%|████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:14<00:00,  5.44s/it]

# %%
textgen.generate_samples(5)
# Out:
# ####################
# Temperature: 0.2
# ####################
#
#
#
#
#
#
#
#
#
#
# ####################
# Temperature: 0.5
# ####################
# b. I am supply for this period.
#
#
#
#
#
#
#
#
#
# ####################
# Temperature: 1.0
# ####################
#
#
#
#
#
#
# c. Cancel capital sectors and arts loan over the air jobs require which and the COVID-19 casieties. For the monthly uncertainties from one year.

# %% [markdown]
# #### References
# https://github.com/minimaxir/textgenrnn
# https://minimaxir.com/2018/05/text-neural-networks/
# https://www.kdnuggets.com/2018/06/generating-text-rnn-4-lines-code.html
